# %% [markdown]
# # AI Forex Quantitative Trading - Training on Colab
#
# This notebook enables you to train LightGBM and 1D-CNN models using Yahoo Finance data directly in Google Colab.

# %% [markdown]
# ## 1. Setup Environment

# %%
# Note: If you are running this in Colab, make sure you have uploaded the LATEST code (src/ and config/) with yfinance changes.
# If you are cloning from git, ensure you have pushed your local changes first.
# !git clone https://github.com/cycxyit/LGBM-forex-new.git project
# %cd project

# !pip install -r requirements.txt
# !pip install ta-lib # Binary install might be needed on Linux (Colab usually handles it via apt first)
# Pre-install TA-Lib binary for Colab (Linux)
# !url="https://launchpad.net/~mario-mariani/+archive/ubuntu/talib/+files"
# !ext="0.4.0-oneiric1_amd64.deb -qO"
# !wget http://prdownloads.sourceforge.net/ta-lib/ta-lib-0.4.0-src.tar.gz
# !tar -xzvf ta-lib-0.4.0-src.tar.gz
# %cd ta-lib
# !./configure --prefix=/usr
# !make
# !make install
# !pip install Ta-Lib
# %cd ..

# %% [markdown]
# ## 2. Configuration

# %%
import os
# API Key not needed for yfinance

# %% [markdown]
# ## 3. Run Training

# %%
from src.train import train_pipeline

train_pipeline()

# %% [markdown]
# ## 4. Download Models

# %%
from google.colab import files

files.download('models/lgbm_model.txt')
files.download('models/cnn_model.keras')
files.download('models/scaler.pkl')

# %% [markdown]
# ## 5. Backtesting

# %%
from src.backtest import Backtester

# Initialize and Run Backtest
backtester = Backtester()
backtester.load_models()
backtester.run_backtest("EURUSD")

# %%
from IPython.display import Image
Image(filename='data/EURUSD_backtest.png')
